# %%
import pandas as pd

# %%
dfBalidanNusa = pd.read_csv('./Ganjar_Bali dan Nusa Tenggara.csv')
dfJakarta = pd.read_csv('./Ganjar_Jakarta.csv')
dfJabar = pd.read_csv('./Ganjar_Jawa Barat.csv')
dfJateng = pd.read_csv('./Ganjar_Jawa Tengah.csv')
dfTimur = pd.read_csv('./Ganjar_Jawa Timur.csv')
dfJogja = pd.read_csv('./Ganjar_Jogja.csv')
dfKalimantan = pd.read_csv('./Ganjar_Kalimantan.csv')
dfPapua = pd.read_csv('./Ganjar_Papua.csv')
dfSulawesi = pd.read_csv('./Ganjar_Sulawesi.csv')
dfSumatera = pd.read_csv('./Ganjar_Sumatera.csv')

# %%
dfConcat = pd.concat([dfBalidanNusa, dfJakarta, dfJabar, dfJateng, dfTimur, dfJogja, dfKalimantan, dfPapua, dfSulawesi, dfSumatera ], ignore_index=True)

# %%
dfConcat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81338 entries, 0 to 81337
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  81338 non-null  int64
#  1   DateTime    81338 non-null  object
#  2   Tweet Id    81338 non-null  float64
#  3   Tweet       81338 non-null  object
#  4   Username    81338 non-null  object
#  5   Location    45600 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.7+ MB

# %%
df_new = dfConcat.loc[:, ['DateTime', 'Tweet Id', 'Tweet', 'Username', 'Location']] # using loc

# %%
df_new = df_new.reset_index(drop=True)

# %%
df_new.to_csv('0. Data_Ganjar_Full.csv')
